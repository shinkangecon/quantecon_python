# %% [markdown]
# <a href="https://colab.research.google.com/github/shinkangecon/quantecon_python/blob/master/Aiyagari_EGM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Intitial Setup**

# %%
# Practice for Aiyagari model
# Initial Setup
import numpy as np
import numba
from scipy import optimize
import matplotlib.pyplot as plt

# some useful plot defaults
plt.rcParams.update({'font.size' : 20, 'lines.linewidth' : 3.5, 'figure.figsize' : (13,7)})

# %% [markdown]
# **Discretization**

# %%
# Asset grid
def asset_grid(amin,amax,na):
  ubar = np.log(1.0 + np.log(1.0 + amax - amin))
  ugrid = np.linspace(0.0, ubar, na)
  return amin + np.exp(np.log(ugrid) - 1.0) - 1.0

# %%
# AR(1) process: Rouwenhorst
def rouwenhorst_Pi(N, p):
    # base case Pi_2
    Pi = np.array([[p, 1 - p],
                   [1 - p, p]])

    # recursion to build up from Pi_2 to Pi_N
    for n in range(3, N + 1):
        Pi_old = Pi
        Pi = np.zeros((n, n))

        Pi[:-1, :-1] += p * Pi_old
        Pi[:-1, 1:] += (1 - p) * Pi_old
        Pi[1:, :-1] += (1 - p) * Pi_old
        Pi[1:, 1:] += p * Pi_old
        Pi[1:-1, :] /= 2

    return Pi

def stationary_markov(Pi, tol=1E-14):
    # start with uniform distribution over all states
    n = Pi.shape[0]
    pi = np.full(n, 1/n)

    # update distribution using Pi until successive iterations differ by less than tol
    for _ in range(10_000):
        pi_new = Pi.T @ pi
        if np.max(np.abs(pi_new - pi)) < tol:
            return pi_new
        pi = pi_new

def discretize_income(rho, sigma, n_e):
    # choose inner-switching probability p to match persistence rho
    p = (1+rho)/2

    # start with states from 0 to n_e-1, scale by alpha to match standard deviation sigma
    e = np.arange(n_e)
    alpha = 2*sigma/np.sqrt(n_e-1)
    e = alpha*e

    # obtain Markov transition matrix Pi and its stationary distribution
    Pi = rouwenhorst_Pi(n_e, p)
    pi = stationary_markov(Pi)

    # e is log income, get income y and scale so that mean is 1
    y = np.exp(e)
    y /= np.vdot(pi, y)

    return y, pi, Pi

# %% [markdown]
# Calibration & Setup Grids, Value & Policy functions

# %%
amin=0.0
amax=200.0
n_a=10_000
rho=0.9
sigma=0.1
n_e=21

# Asset grid
agrid=asset_grid(amin,amax,n_a)

# Productivity grid
ygrid, pi, Pi=discretize_income(rho, sigma, n_e)

# Value functions & Policy functions
V, NewV, gc, gn = np.zeros((n_a, n_e)), np.zeros((n_a, n_e)), np.zeros((n_a, n_e)), np.zeros((n_a, n_e))

ygrid, pi, Pi
# Out:
# <ipython-input-15-e8c278a17d29>:5: RuntimeWarning: divide by zero encountered in log
#   return amin + np.exp(np.log(ugrid) - 1.0) - 1.0
# (array([0.63621853, 0.66531689, 0.69574612, 0.72756706, 0.76084339,
#         0.79564165, 0.83203146, 0.87008562, 0.90988023, 0.95149491,
#         0.99501289, 1.04052124, 1.08811097, 1.13787728, 1.18991973,
#         1.24434242, 1.30125421, 1.36076894, 1.42300565, 1.48808886,
#         1.55614874]),
#  array([9.53674316e-07, 1.90734863e-05, 1.81198120e-04, 1.08718872e-03,
#         4.62055206e-03, 1.47857666e-02, 3.69644165e-02, 7.39288330e-02,
#         1.20134354e-01, 1.60179138e-01, 1.76197052e-01, 1.60179138e-01,
#         1.20134354e-01, 7.39288330e-02, 3.69644165e-02, 1.47857666e-02,
#         4.62055206e-03, 1.08718872e-03, 1.81198120e-04, 1.90734863e-05,
#         9.53674316e-07]),
#  array([[3.58485922e-01, 3.77353603e-01, 1.88676801e-01, 5.95821478e-02,
#          1.33275857e-02, 2.24464601e-03, 2.95348159e-04, 3.10892799e-05,
#          2.65895157e-06, 1.86593093e-07, 1.08027580e-08, 5.16878373e-10,
#          2.04030937e-11, 6.60828945e-13, 1.73902354e-14, 3.66110219e-16,
#          6.02154965e-18, 7.45702744e-20, 6.54125214e-22, 3.62396240e-24,
#          9.53674316e-27],
#         [1.88676801e-02, 3.77353603e-01, 3.67423245e-01, 1.72474638e-01,
#          5.12059871e-02, 1.07506730e-02, 1.69436576e-03, 2.07807292e-04,
#          2.02919988e-05, 1.60077232e-06, 1.02910484e-07, 5.41362086e-09,
#          2.33024807e-10, 8.17341064e-12, 2.31564713e-13, 5.22188786e-15,
#          9.15909395e-17, 1.20489864e-18, 1.11889839e-20, 6.54220581e-23,
#          1.81198120e-25],
#         [9.93035796e-04, 3.86761310e-02, 3.94656082e-01, 3.55729484e-01,
#          1.56447086e-01, 4.35377549e-02, 8.54838936e-03, 1.25538775e-03,
#          1.42802252e-04, 1.28603420e-05, 9.29328559e-07, 5.42833821e-08,
#          2.56886521e-09, 9.82515543e-11, 3.01446382e-12, 7.31835593e-14,
#          1.37494216e-15, 1.92889784e-17, 1.90278149e-19, 1.17778778e-21,
#          3.44276428e-24],
#         [5.22650419e-05, 3.02587085e-03, 5.92882474e-02, 4.10258253e-01,
#          3.42371002e-01, 1.40719020e-01, 3.65814059e-02, 6.68912525e-03,
#          9.10844436e-04, 9.55399317e-05, 7.88083656e-06, 5.17404707e-07,
#          2.71867589e-08, 1.14315430e-09, 3.82441947e-11, 1.00546323e-12,
#          2.03368071e-14, 3.05599103e-16, 3.21482973e-18, 2.11385727e-20,
#          6.54125214e-23],
#         [2.75079168e-06, 2.11376624e-04, 6.13517983e-03, 8.05578828e-02,
#          4.24037890e-01, 3.27459482e-01, 1.25409648e-01, 3.03329573e-02,
#          5.14059299e-03, 6.45315328e-04, 6.19907479e-05, 4.64539745e-06,
#          2.74340987e-07, 1.28079256e-08, 4.71065802e-10, 1.35041768e-11,
#          2.95787443e-13, 4.78513107e-15, 5.39193004e-17, 3.78084373e-19,
#          1.24283791e-21],
#         [1.44778509e-07, 1.38682572e-05, 5.33550917e-04, 1.03469868e-02,
#          1.02331088e-01, 4.35886753e-01, 3.11118582e-01, 1.10631457e-01,
#          2.47808066e-02, 3.87030398e-03, 4.44877790e-04, 3.88206220e-05,
#          2.61664581e-06, 1.37296887e-07, 5.60656656e-09, 1.76694097e-10,
#          4.22005526e-12, 7.39311201e-14, 8.96857344e-16, 6.73618145e-18,
#          2.36139202e-20],
#         [7.61992155e-09, 8.74285736e-07, 4.19038694e-05, 1.07592370e-03,
#          1.56762060e-02, 1.24447433e-01, 4.45711551e-01, 2.93482788e-01,
#          9.64892474e-02, 1.99061253e-02, 2.84602779e-03, 2.97130044e-04,
#          2.33199168e-05, 1.39650792e-06, 6.40915529e-08, 2.24262663e-09,
#          5.88832252e-11, 1.12482925e-12, 1.47767834e-14, 1.19486436e-16,
#          4.48664484e-19],
#         [4.01048503e-10, 5.36138524e-08, 3.07693076e-06, 9.83694889e-05,
#          1.89580983e-03, 2.21262914e-02, 1.46741394e-01, 4.53434782e-01,
#          2.74696181e-01, 8.30792445e-02, 1.56833245e-02, 2.03622808e-03,
#          1.91187509e-04, 1.33309168e-05, 6.98253960e-07, 2.74593775e-08,
#          8.00495350e-10, 1.68110926e-11, 2.40812633e-13, 2.10872307e-15,
#          8.52462520e-18],
#         [2.11078159e-11, 3.22171927e-09, 2.15388013e-07, 8.24293608e-06,
#          1.97715115e-04, 3.04994543e-03, 2.96889992e-02, 1.69043803e-01,
#          4.58995433e-01, 2.54911118e-01, 7.04883080e-02, 1.20805834e-02,
#          1.41047040e-03, 1.17653852e-04, 7.17535903e-06, 3.22048715e-07,
#          1.05515764e-08, 2.46034017e-10, 3.87460816e-12, 3.69968734e-14,
#          1.61967879e-16],
#         [1.11093768e-12, 1.90613518e-10, 1.45478982e-08, 6.48461075e-07,
#          1.86148652e-05, 3.57258829e-04, 4.59372123e-03, 3.83442667e-02,
#          1.91183339e-01, 4.62349527e-01, 2.34286843e-01, 5.87932417e-02,
#          9.06043757e-03, 9.39797577e-04, 6.85684717e-05, 3.58344203e-06,
#          1.34001849e-07, 3.51179665e-09, 6.14065409e-11, 6.44632157e-13,
#          3.07738970e-15],
#         [5.84704042e-14, 1.11401507e-11, 9.55706046e-10, 4.86271281e-08,
#          1.62563150e-06, 3.73324019e-05, 5.97068767e-04, 6.58041586e-03,
#          4.80602100e-02, 2.12988039e-01, 4.63470517e-01, 2.12988039e-01,
#          4.80602100e-02, 6.58041586e-03, 5.97068767e-04, 3.73324019e-05,
#          1.62563150e-06, 4.86271281e-08, 9.55706046e-10, 1.11401507e-11,
#          5.84704042e-14],
#         [3.07738970e-15, 6.44632157e-13, 6.14065409e-11, 3.51179665e-09,
#          1.34001849e-07, 3.58344203e-06, 6.85684717e-05, 9.39797577e-04,
#          9.06043757e-03, 5.87932417e-02, 2.34286843e-01, 4.62349527e-01,
#          1.91183339e-01, 3.83442667e-02, 4.59372123e-03, 3.57258829e-04,
#          1.86148652e-05, 6.48461075e-07, 1.45478982e-08, 1.90613518e-10,
#          1.11093768e-12],
#         [1.61967879e-16, 3.69968734e-14, 3.87460816e-12, 2.46034017e-10,
#          1.05515764e-08, 3.22048715e-07, 7.17535903e-06, 1.17653852e-04,
#          1.41047040e-03, 1.20805834e-02, 7.04883080e-02, 2.54911118e-01,
#          4.58995433e-01, 1.69043803e-01, 2.96889992e-02, 3.04994543e-03,
#          1.97715115e-04, 8.24293608e-06, 2.15388013e-07, 3.22171927e-09,
#          2.11078159e-11],
#         [8.52462520e-18, 2.10872307e-15, 2.40812633e-13, 1.68110926e-11,
#          8.00495350e-10, 2.74593775e-08, 6.98253960e-07, 1.33309168e-05,
#          1.91187509e-04, 2.03622808e-03, 1.56833245e-02, 8.30792445e-02,
#          2.74696181e-01, 4.53434782e-01, 1.46741394e-01, 2.21262914e-02,
#          1.89580983e-03, 9.83694889e-05, 3.07693076e-06, 5.36138524e-08,
#          4.01048503e-10],
#         [4.48664484e-19, 1.19486436e-16, 1.47767834e-14, 1.12482925e-12,
#          5.88832252e-11, 2.24262663e-09, 6.40915529e-08, 1.39650792e-06,
#          2.33199168e-05, 2.97130044e-04, 2.84602779e-03, 1.99061253e-02,
#          9.64892474e-02, 2.93482788e-01, 4.45711551e-01, 1.24447433e-01,
#          1.56762060e-02, 1.07592370e-03, 4.19038694e-05, 8.74285736e-07,
#          7.61992155e-09],
#         [2.36139202e-20, 6.73618145e-18, 8.96857344e-16, 7.39311201e-14,
#          4.22005526e-12, 1.76694097e-10, 5.60656656e-09, 1.37296887e-07,
#          2.61664581e-06, 3.88206220e-05, 4.44877790e-04, 3.87030398e-03,
#          2.47808066e-02, 1.10631457e-01, 3.11118582e-01, 4.35886753e-01,
#          1.02331088e-01, 1.03469868e-02, 5.33550917e-04, 1.38682572e-05,
#          1.44778509e-07],
#         [1.24283791e-21, 3.78084373e-19, 5.39193004e-17, 4.78513107e-15,
#          2.95787443e-13, 1.35041768e-11, 4.71065802e-10, 1.28079256e-08,
#          2.74340987e-07, 4.64539745e-06, 6.19907479e-05, 6.45315328e-04,
#          5.14059299e-03, 3.03329573e-02, 1.25409648e-01, 3.27459482e-01,
#          4.24037890e-01, 8.05578828e-02, 6.13517983e-03, 2.11376624e-04,
#          2.75079168e-06],
#         [6.54125214e-23, 2.11385727e-20, 3.21482973e-18, 3.05599103e-16,
#          2.03368071e-14, 1.00546323e-12, 3.82441947e-11, 1.14315430e-09,
#          2.71867589e-08, 5.17404707e-07, 7.88083656e-06, 9.55399317e-05,
#          9.10844436e-04, 6.68912525e-03, 3.65814059e-02, 1.40719020e-01,
#          3.42371002e-01, 4.10258253e-01, 5.92882474e-02, 3.02587085e-03,
#          5.22650419e-05],
#         [3.44276428e-24, 1.17778778e-21, 1.90278149e-19, 1.92889784e-17,
#          1.37494216e-15, 7.31835593e-14, 3.01446382e-12, 9.82515543e-11,
#          2.56886521e-09, 5.42833821e-08, 9.29328559e-07, 1.28603420e-05,
#          1.42802252e-04, 1.25538775e-03, 8.54838936e-03, 4.35377549e-02,
#          1.56447086e-01, 3.55729484e-01, 3.94656082e-01, 3.86761310e-02,
#          9.93035796e-04],
#         [1.81198120e-25, 6.54220581e-23, 1.11889839e-20, 1.20489864e-18,
#          9.15909395e-17, 5.22188786e-15, 2.31564713e-13, 8.17341064e-12,
#          2.33024807e-10, 5.41362086e-09, 1.02910484e-07, 1.60077232e-06,
#          2.02919988e-05, 2.07807292e-04, 1.69436576e-03, 1.07506730e-02,
#          5.12059871e-02, 1.72474638e-01, 3.67423245e-01, 3.77353603e-01,
#          1.88676801e-02],
#         [9.53674316e-27, 3.62396240e-24, 6.54125214e-22, 7.45702744e-20,
#          6.02154965e-18, 3.66110219e-16, 1.73902354e-14, 6.60828945e-13,
#          2.04030937e-11, 5.16878373e-10, 1.08027580e-08, 1.86593093e-07,
#          2.65895157e-06, 3.10892799e-05, 2.95348159e-04, 2.24464601e-03,
#          1.33275857e-02, 5.95821478e-02, 1.88676801e-01, 3.77353603e-01,
#          3.58485922e-01]]))
